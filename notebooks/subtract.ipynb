# %%
def subtract(a,b):

    return a - b

print(subtract(20, 10))
# Out:
# 10

# %%
def distance_from_zero(c):
    if c < 0:
        ans = subtract(0, c)
    else: 
        ans = c
    return ans

# %%
print(distance_from_zero(-10))
# Out:
# 10
