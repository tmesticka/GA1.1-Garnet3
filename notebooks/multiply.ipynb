# %% [markdown]
# ### Team C base function: Multiplying
# This notebook focuses onb creating the multiplying function for our MUDE Week 1 group assignment.

# %%
def multiply (a, b):  
    return a * b

print(multiply(2, 3))

# %%
def square (x):
    return multiply(x, x)

print(square(5))
