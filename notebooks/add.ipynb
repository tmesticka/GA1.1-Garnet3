# %%
def add(a, b):
    ans = a + b
    return ans

print(add(3, 4))
# Out:
# 7

# %%
print(add(10, 20))
# Out:
# 30

# %%
def sum_list(values):
    total = 0
    for val in values:
        total = add(total, val)
    return total
